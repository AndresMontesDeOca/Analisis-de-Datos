# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresMontesDeOca/Analisis-de-Datos/blob/main/TP_Grupal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TP Grupal

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Data Load

# %%
url = 'https://data.insideairbnb.com/argentina/ciudad-aut%C3%B3noma-de-buenos-aires/buenos-aires/2026-01-25/data/listings.csv.gz'
data = pd.read_csv(url)

print(data.info())
display(data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27348 entries, 0 to 27347
# Data columns (total 85 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            27348 non-null  int64
#  1   listing_url                                   27348 non-null  object
#  2   scrape_id                                     27348 non-null  int64
#  3   last_scraped                                  27348 non-null  object
#  4   source                                        27348 non-null  object
#  5   name                                          27348 non-null  object
#  6   description                                   26752 non-null  object
#  7   neighborhood_overview                         0 non-null      float64
#  8   picture_url                                   27347 non-null  object
# ...

# %% [markdown]
# ## Nulls

# %%
# 1. Preparar los datos
null_data = data.isnull().mean().reset_index()
null_data.columns = ['column', 'ratio']
null_data = null_data[null_data['ratio'] > 0].sort_values('ratio', ascending=False)

# 2. Plotear
plt.figure(figsize=(10, 6))
sns.barplot(data=null_data, x='ratio', y='column', palette='Reds_r')

# Añadimos una línea guía para el 50% o 70% (umbral común para borrar columnas)
plt.axvline(0.5, color='black', linestyle='--')
plt.title('Ratio de valores nulos por columna (Solo columnas con nulos)')
plt.xlabel('Proporción de Nulos (0.0 a 1.0)')
plt.show()

# %%
# Solo columnas con al menos un nulo
cols_con_nulos = data.columns[data.isnull().any()]

# Configuramos el tamaño de la figura antes de llamar a msno
plt.figure(figsize=(12, 7))

# Personalizamos la matriz
# El color (0.2, 0.4, 0.6) es un azul acero elegante
msno.matrix(data[cols_con_nulos],
            figsize=(12, 7),
            color=(0.2, 0.4, 0.6),
            fontsize=12,
            sparkline=True,
            labels=True)

# Agregamos un título profesional con Matplotlib
plt.title('Mapa de Calor de Datos Faltantes', fontsize=20, pad=20)

plt.show()

# %%
m

# %% [markdown]
# ## Barrios

# %%
data.neighbourhood_cleansed.value_counts(normalize=True).round(2)
# Out:
# neighbourhood_cleansed
# Palermo              0.33
# Recoleta             0.14
# San Nicolas          0.08
# Belgrano             0.05
# Retiro               0.05
# Monserrat            0.05
# Balvanera            0.04
# Almagro              0.04
# Villa Crespo         0.03
# San Telmo            0.03
# Colegiales           0.02
# Chacarita            0.02
# Nuñez                0.02
# Caballito            0.02
# Constitucion         0.01
# Puerto Madero        0.01
# Villa Urquiza        0.01
# Barracas             0.01
# Saavedra             0.01
# San Cristobal        0.01
# Flores               0.00
# Villa Del Parque     0.00
# Boca                 0.00
# Coghlan              0.00
# Villa Ortuzar        0.00
# Boedo                0.00
# Villa Devoto         0.00
# Parque Patricios     0.00
# Parque Chacabuco     0.00
# Parque Chas          0.00
# Paternal             0.00
# Villa Pueyrredon     0.00
# Floresta             0.00
# Villa Luro           0.00
# ...

# %% [markdown]
# ## Fechas

# %%
data.calendar_last_scraped.value_counts()
# Out:
# calendar_last_scraped
# 2026-01-25    14113
# 2026-01-26    13235
# Name: count, dtype: int64
